# %%
import numpy as np
from matplotlib import pyplot as plt
# 添加图形对象
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
langs = ['C','C++','Java','Python','JavaScript']
students = [20,15,37,30,31]
ax.pie(students,labels = langs,autopct='%1.2f%%')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# 设置中文显示
plt.rcParams['font.sans-serif'] = 'SimHei' 
plt.rcParams['axes.unicode_minus'] = False
data = pd.read_csv('../data/people.csv')
name = data.columns # 提取其中的columns字段,视为数据的标签
values = data.values # 提取其中的values字段,表示数据的存在位置
label = ['0-14岁人口','15-64岁人口','65岁及以上人口'] # 刻度标签
plt.figure(figsize=(6,6))
explode = [0.01,0.01,0.2] # 设置各项离心n个半径
plt.title('2019年各年龄段总人口饼图') # 图标标题
plt.pie(values[-1,2:5],explode=explode,labels = label,autopct='%1.1f%%',startangle=90)
plt.savefig('../tmp/2019年各年龄段年末总人口饼图.png')
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['C','C++','Java','Python','JavaScript']
students = [20,15,37,30,31]
ax.bar(langs,students)
plt.show()

# %%
label = ['0-14岁人口','15-64岁人口','65及以上人口'] # 可读标签
plt.figure(figsize=(9,7),dpi=60)
plt.xlabel('年龄段') # 添加x轴标签
plt.ylabel('年末总人口(万人)') # 添加y轴标签
plt.xticks(range(3),label)
plt.title('2019年各年龄段年末总人口柱形图') # 添加图表标题
plt.bar(range(3),values[-1,2:5],width=0.4)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.figure(figsize=(9,7))
data = [[30,25,50,20],
       [40,23,51,17],
       [35,22,45,19]]
X = np.arange(4)
plt.xticks(range(4),X)
plt.bar(X,data[0],width=0.25)
plt.bar(X + 0.25,data[1],width=0.25)
plt.bar(X + 0.5,data[2],width=0.25)
# Out:
# <BarContainer object of 4 artists>

# %%
mean, sigma = 0,1
x = mean+sigma * np.random.randn(10000)
plt.hist(x,50,histtype='bar')
plt.show()

# %%
np.random.seed(10)
collectn_1 = np.random.normal(100,10,200)
collectn_2 = np.random.normal(80,30,200)
collectn_3 = np.random.normal(90,20,200)
collectn_4 = np.random.normal(70,25,200)
data_to_plot = [collectn_1,collectn_2,collectn_3,collectn_4]
plt.figure(figsize=(9,7))
plt.boxplot(data_to_plot)
plt.show()

# %%
label = ['0-14岁人口','15-64岁人口','65及以上人口'] # 添加刻度标签
rks = (list(values[:,2]),list(values[:,3]),list(values[:,4]))
plt.figure(figsize=(9,7))
plt.title('2000-2019年各年龄段人口数箱线图')
plt.boxplot(rks,labels=label,notch=True,meanline=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x122f83340>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x122f837f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x122f82fb0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x122f83e50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x122cb3f70>,
# ...
#  'means': []}
